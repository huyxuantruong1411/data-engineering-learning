# %%
import time
import requests
from datetime import datetime

BASE_URL = "https://api.mangadex.org/manga"
RESULTS = []

# Cấu hình
MIN_DELAY = 0.25
delay = 0.0  # ban đầu spam liên tục
MAX_RETRIES = 5
BURST_SUCCESS_THRESHOLD = 8  # số lần thành công liên tiếp để quay lại spam
success_streak = 0

def fetch_all_manga():
    global delay, success_streak
    limit = 100
    created_at_since = "1900-01-01T00:00:00"  # lấy từ đầu

    while True:
        params = {
            "limit": limit,
            "order[createdAt]": "asc",
            "createdAtSince": created_at_since,
            "includes[]": ["author", "artist", "cover_art"]
        }

        retries = 0
        success = False

        while not success and retries < MAX_RETRIES:
            try:
                resp = requests.get(BASE_URL, params=params, timeout=30)

                if resp.status_code == 200:
                    batch = resp.json()
                    data_list = batch.get("data", [])

                    if not data_list:
                        print("🏁 Hoàn tất!")
                        return RESULTS

                    for manga in data_list:
                        RESULTS.append(manga)

                    last_created = data_list[-1]["attributes"]["createdAt"]
                    created_at_since = _add_one_second(last_created)

                    print(f"✅ Lấy {len(data_list)} manga, tổng cộng: {len(RESULTS)} | delay={delay:.2f}s")

                    # Burst mode logic
                    success_streak += 1
                    if delay > 0:  # đang trong chế độ delay
                        delay = max(MIN_DELAY, delay * 0.9)  # giảm delay dần
                        if success_streak >= BURST_SUCCESS_THRESHOLD:
                            delay = 0.0  # quay lại spam mode
                            print("🚀 Quay lại SPAM MODE")
                    success = True

                else:
                    raise Exception(f"HTTP {resp.status_code}")

            except Exception as e:
                retries += 1
                success_streak = 0
                # bật chế độ delay adaptive khi gặp lỗi
                if delay == 0.0:
                    delay = MIN_DELAY
                delay *= 2
                print(f"⚠️ Lỗi: {e}. Retry {retries}/{MAX_RETRIES}, delay={delay:.2f}s")
                time.sleep(delay)

        if not success:
            print(f"❌ Dừng vì lỗi liên tục tại mốc {created_at_since}")
            break

        if delay > 0:
            time.sleep(delay)  # áp dụng delay khi không ở spam mode

def _add_one_second(timestr):
    """Tăng thêm 1 giây cho mốc thời gian ISO8601"""
    dt = datetime.fromisoformat(timestr.replace("Z", "+00:00"))
    dt_plus = dt.timestamp() + 1
    return datetime.utcfromtimestamp(dt_plus).strftime("%Y-%m-%dT%H:%M:%S")

# %%
# Chạy crawler
all_manga = fetch_all_manga()

# Kiểm tra nhanh
print(f"Thu được {len(all_manga)} manga")
all_manga[0]  # xem thử phần tử đầu tiên

# %%
import json

with open("manga_data.json", "w", encoding="utf-8") as f:
    json.dump(all_manga, f, ensure_ascii=False, indent=2)

print("💾 Đã lưu ra manga_data.json")

# %%
import time
import requests
from datetime import datetime
from pymongo import MongoClient

# %%
# ===== MongoDB setup =====
mongo_client = MongoClient("mongodb://localhost:27017/")
db = mongo_client["manga_raw_data"]
collection = db["mangadex_manga"]

# %%
# ===== API config =====
BASE_URL = "https://api.mangadex.org/manga"
MIN_DELAY = 0.25
delay = 0.0
MAX_RETRIES = 5
BURST_SUCCESS_THRESHOLD = 8
success_streak = 0

# %%
def fetch_all_manga():
    global delay, success_streak
    limit = 100
    created_at_since = "1900-01-01T00:00:00"

    while True:
        params = {
            "limit": limit,
            "order[createdAt]": "asc",
            "createdAtSince": created_at_since,
            "includes[]": ["author", "artist", "cover_art"]
        }

        retries = 0
        success = False

        while not success and retries < MAX_RETRIES:
            try:
                resp = requests.get(BASE_URL, params=params, timeout=30)

                if resp.status_code == 200:
                    batch = resp.json()
                    data_list = batch.get("data", [])

                    if not data_list:
                        print("🏁 Hoàn tất!")
                        return

                    # lưu từng manga vào MongoDB
                    for manga in data_list:
                        collection.insert_one(manga)

                    last_created = data_list[-1]["attributes"]["createdAt"]
                    created_at_since = _add_one_second(last_created)

                    total_count = collection.count_documents({})
                    print(f"✅ Lấy {len(data_list)} manga, tổng cộng trong DB: {total_count} | delay={delay:.2f}s")

                    # Burst mode logic
                    success_streak += 1
                    if delay > 0:
                        delay = max(MIN_DELAY, delay * 0.9)
                        if success_streak >= BURST_SUCCESS_THRESHOLD:
                            delay = 0.0
                            print("🚀 Quay lại SPAM MODE")
                    success = True

                else:
                    raise Exception(f"HTTP {resp.status_code}")

            except Exception as e:
                retries += 1
                success_streak = 0
                if delay == 0.0:
                    delay = MIN_DELAY
                delay *= 2
                print(f"⚠️ Lỗi: {e}. Retry {retries}/{MAX_RETRIES}, delay={delay:.2f}s")
                time.sleep(delay)

        if not success:
            print(f"❌ Dừng vì lỗi liên tục tại mốc {created_at_since}")
            break

        if delay > 0:
            time.sleep(delay)

# %%
def _add_one_second(timestr):
    dt = datetime.fromisoformat(timestr.replace("Z", "+00:00"))
    dt_plus = dt.timestamp() + 1
    return datetime.utcfromtimestamp(dt_plus).strftime("%Y-%m-%dT%H:%M:%S")

# %%
# Chạy để fetch và lưu thẳng vào MongoDB
fetch_all_manga()
# Out:
# C:\Users\Huy\AppData\Local\Temp\ipykernel_28164\2656471103.py:4: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return datetime.utcfromtimestamp(dt_plus).strftime("%Y-%m-%dT%H:%M:%S")
# ✅ Lấy 100 manga, tổng cộng trong DB: 100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 1900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 2900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 3900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 4900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 5900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 6900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 7900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 8900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 9900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 10900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 11900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 12900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 13900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 14900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 15900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 16900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 17900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 18900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 19900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 20800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB:
 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 62400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 62500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 62600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 62700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 62800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 62900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 63900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 64900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 65900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 66900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 67900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 68900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 69900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 70900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 71900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 72900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 73900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 74900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 75900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 76900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 77900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 78900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 79900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 80900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 81900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 82900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 83900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 84900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85800 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 85900 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86000 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86100 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86200 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86300 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86400 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86500 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86600 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86700 | delay=0.00s
# ✅ Lấy 100 manga, tổng cộng trong DB: 86800 | delay=0.00s
# ✅ Lấy 62 manga, tổng cộng trong DB: 86862 | delay=0.00s
# 🏁 Hoàn tất!

# %%
old_db = mongo_client["mangadex_raw_data"]
old_collection = old_db["mangadex_manga"]

new_db = mongo_client["manga_raw_data"]
new_collection = new_db["mangadex_manga"]

# %%
# Lấy toàn bộ dữ liệu từ collection cũ
docs = list(old_collection.find({}))

if docs:
    # Xóa _id cũ để MongoDB tự tạo lại (tránh trùng _id)
    for d in docs:
        d.pop("_id", None)

    # Insert sang DB mới
    new_collection.insert_many(docs)
    print(f"✅ Đã copy {len(docs)} document sang 'manga_raw_data.mangadex_manga'")

    # (Tuỳ chọn) Xoá collection cũ
    # old_collection.drop()
# Out:
# ✅ Đã copy 86862 document sang 'manga_raw_data.mangadex_manga'

# %%
import json
from pymongo import MongoClient

# Kết nối MongoDB
mongo_client = MongoClient("mongodb://localhost:27017/")
db = mongo_client["mangadex_raw_data"]
collection = db["manga"]

# Đọc dữ liệu từ file
with open("manga_data.json", "r", encoding="utf-8") as f:
    manga_list = json.load(f)

# Lưu vào MongoDB
if isinstance(manga_list, list):
    collection.insert_many(manga_list)
else:
    print("⚠️ File không chứa list!")

print(f"✅ Đã insert {collection.count_documents({})} tài liệu vào MongoDB.")
